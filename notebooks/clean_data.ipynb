# %% [markdown]
# ### Chargement des librairies

# %%
import pandas as pd
import numpy as np

# %%
# Load the data
data_file= r"C:\Users\djamb\OneDrive - Université Centrale\ML PROJECTS\PREDICTION PRIX LOGEMENT\data\housing_data_sklearn.csv"
data = pd.read_csv(data_file)

# %%
df = data.copy()

# %%
df.head(10)
# Out:
#        CRIM    ZN INDUS CHAS    NOX     RM   AGE     DIS RAD  TAX PTRATIO  \
# 1   0.00632    18  2.31    0  0.538  6.575  65.2    4.09   1  296    15.3
# 2   0.02731     0  7.07    0  0.469  6.421  78.9  4.9671   2  242    17.8
# 3   0.02729     0  7.07    0  0.469  7.185  61.1  4.9671   2  242    17.8
# 4   0.03237     0  2.18    0  0.458  6.998  45.8  6.0622   3  222    18.7
# 5   0.06905     0  2.18    0  0.458  7.147  54.2  6.0622   3  222    18.7
# 6   0.02985     0  2.18    0  0.458   6.43  58.7  6.0622   3  222    18.7
# 7   0.08829  12.5  7.87    0  0.524  6.012  66.6  5.5605   5  311    15.2
# 8   0.14455  12.5  7.87    0  0.524  6.172  96.1  5.9505   5  311    15.2
# 9   0.21124  12.5  7.87    0  0.524  5.631   100  6.0821   5  311    15.2
# 10  0.17004  12.5  7.87    0  0.524  6.004  85.9  6.5921   5  311    15.2
#
#          B  LSTAT  MEDV
# 1    396.9   4.98    24
# 2    396.9   9.14  21.6
# 3   392.83   4.03  34.7
# 4   394.63   2.94  33.4
# 5    396.9   5.33  36.2
# ...

# %%
# Apercu rapide de l'ensemble de donnée

df.describe().style.background_gradient(cmap='inferno', axis=None)
# Out:
# <style type="text/css">
# </style>
# <table id="T_997d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_997d6_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_997d6_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_997d6_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_997d6_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_997d6_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_997d6_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_997d6_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_997d6_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_997d6_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_997d6_level0_col9" class="col_heading level0 col9" >TAX</th>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 1 to 506
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    object
#  1   ZN       506 non-null    object
#  2   INDUS    506 non-null    object
#  3   CHAS     506 non-null    object
#  4   NOX      506 non-null    object
#  5   RM       506 non-null    object
#  6   AGE      506 non-null    object
#  7   DIS      506 non-null    object
#  8   RAD      506 non-null    object
#  9   TAX      506 non-null    object
#  10  PTRATIO  506 non-null    object
#  11  B        506 non-null    object
#  12  LSTAT    506 non-null    object
#  13  MEDV     506 non-null    object
# dtypes: object(14)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
#Rename columns
def rename_columns_(df):
    # Dictionnaire de correspondance des anciens et nouveaux noms de colonnes
    column_mapping = {
        'CRIM': 'PerCapCrimeRate',
        'ZN': 'ResidentialLandOver25K',
        'INDUS': 'NonRetailAcresRatio',
        'CHAS': 'CharlesRiverDummy',
        'NOX': 'NitricOxideConc',
        'RM': 'AvgNumRooms',
        'AGE': 'Pre1940sOwnerOcc',
        'DIS': 'WeightedDistToEmploy',
        'RAD': 'RadialHighwayAccessIndex',
        'TAX': 'MedianHomeTaxRate',
        'PTRATIO': 'PupilTeacherRatio',
        'B': 'AfroAmericanProportion',
        'LSTAT': 'LowerStatusRatio',
        'MEDV': 'MedianHomeValue'
    }
    
    # Renommer les colonnes dans le DataFrame
    df.rename(columns=column_mapping, inplace=True)
    
    return df

# %%
df = rename_columns_(df)

# %%
df.head()
# Out:
#   PerCapCrimeRate ResidentialLandOver25K NonRetailAcresRatio  \
# 0            CRIM                     ZN               INDUS
# 1         0.00632                     18                2.31
# 2         0.02731                      0                7.07
# 3         0.02729                      0                7.07
# 4         0.03237                      0                2.18
#
#   CharlesRiverDummy NitricOxideConc AvgNumRooms Pre1940sOwnerOcc  \
# 0              CHAS             NOX          RM              AGE
# 1                 0           0.538       6.575             65.2
# 2                 0           0.469       6.421             78.9
# 3                 0           0.469       7.185             61.1
# 4                 0           0.458       6.998             45.8
#
#   WeightedDistToEmploy RadialHighwayAccessIndex MedianHomeTaxRate  \
# 0                  DIS                      RAD               TAX
# 1                 4.09                        1               296
# ...

# %%
filename = r"C:\Users\djamb\OneDrive - Université Centrale\ML PROJECTS\PREDICTION PRIX LOGEMENT\data\housing_data.csv"
df.to_csv(filename, index=False)
